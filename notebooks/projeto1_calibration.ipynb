# %% [markdown]
# # Calibra??o do modelo CIR a curvas de mercado

# %% [markdown]
# Notebook ilustrativo: baixa dados DI, gera curva alvo e calibra par?metros do CIR.

# %%
# %matplotlib inline
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# TODO: completar com l?gica de calibra??o.
